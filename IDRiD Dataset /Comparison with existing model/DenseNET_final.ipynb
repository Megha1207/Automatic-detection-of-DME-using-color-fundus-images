# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize, LabelEncoder
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = tf.keras.preprocessing.image.load_img(os.path.join(folder, filename), target_size=(224, 224))
        img = tf.keras.preprocessing.image.img_to_array(img)
        images.append(img)
    return np.array(images)

def load_labels_from_csv(file_path):
    df = pd.read_csv(file_path)
    return df['Risk of macular edema '].values  # Use the correct column name here

# %%
# Load image from the dataset
train_data_dir = '1. Original Images/a. Training Set'
test_data_dir = '1. Original Images/b. Testing Set'
train_csv_path = '2. Groundtruths/a. IDRiD_Disease Grading_Training Labels.csv'
test_csv_path = '2. Groundtruths/b. IDRiD_Disease Grading_Testing Labels.csv'

# %%
# Read train and test CSV files with specific columns
train_df = pd.read_csv(train_csv_path, usecols=['Image name', 'Risk of macular edema '])
test_df = pd.read_csv(test_csv_path, usecols=['Image name', 'Risk of macular edema '])

# Convert 'Risk of macular edema' column to string type
train_df['Risk of macular edema '] = train_df['Risk of macular edema '].astype(str)
test_df['Risk of macular edema '] = test_df['Risk of macular edema '].astype(str)

train_df['Image name'] = train_df['Image name'].astype(str) + '.jpg'
test_df['Image name'] = test_df['Image name'].astype(str) + '.jpg'

# %%
# Define function to read images and labels from dataset
def read_images_and_labels(data_path, annotation_df):
    data = []
    for index, row in annotation_df.iterrows():
        image_name = row['Image name']
        label = row['Risk of macular edema ']
        image_path = os.path.join(data_path, image_name)
        image = cv2.imread(image_path)  # assuming in OpenCV compatible format
        image = cv2.resize(image, (224, 224))
        data.append([image, label])
    return data

# %%
# Read images and labels using DataFrames
train_data = read_images_and_labels(train_data_dir, train_df)
test_data = read_images_and_labels(test_data_dir, test_df)

# Combine data
data = train_data + test_data

print("Data reading done")
# Out:
# Data reading done

# %%
# Preprocess the data
np.random.shuffle(data)
X = []
y = []

for features, label in data:
    X.append(features)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %%
# Stratified splitting for train-test split
n_splits = 1
test_size = 0.2
stratified_split = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=43)

for train_index, test_index in stratified_split.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
# Further split training data into training and validation sets
for train_index, val_index in stratified_split.split(X_train, y_train):
    X_train, X_val = X_train[train_index], X_train[val_index]
    y_train, y_val = y_train[train_index], y_train[val_index]

# One-hot encode the labels
train_labels = to_categorical(y_train, num_classes=3)
val_labels = to_categorical(y_val, num_classes=3)
test_labels_one_hot = to_categorical(y_test, num_classes=3)

print("Data preprocessing done")
# Out:
# Data preprocessing done

# %%
# Check classwise distribution in train, test, and validation sets
unique_classes = np.unique(np.concatenate((y_train, y_test, y_val)))
for class_label in unique_classes:
    print(f"Class {class_label}:")
    print(f"Train: {np.sum(y_train == class_label)} images")
    print(f"Test: {np.sum(y_test == class_label)} images")
    print(f"Validation: {np.sum(y_val == class_label)} images")
    print('.........')
# Out:
# Class 0:
# Train: 141 images
# Test: 45 images
# Validation: 36 images
# .........
# Class 1:
# Train: 33 images
# Test: 10 images
# Validation: 8 images
# .........
# Class 2:
# Train: 155 images
# Test: 49 images
# Validation: 39 images
# .........

# %%
# Define DenseNet121 model
base_model_densenet = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x = base_model_densenet.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

model_densenet = Model(inputs=base_model_densenet.input, outputs=predictions)

for layer in base_model_densenet.layers:
    layer.trainable = False

model_densenet.compile(optimizer=Adam(learning_rate=0.0007), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 4s 0us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
# Train the DenseNet121 model
history_densenet = model_densenet.fit(X_train, train_labels, validation_data=(X_val, val_labels), epochs=30, batch_size=10)
# Out:
# Epoch 1/30
# 33/33 [==============================] - 38s 1s/step - loss: 94.6445 - accuracy: 0.4772 - val_loss: 109.1106 - val_accuracy: 0.4699
# Epoch 2/30
# 33/33 [==============================] - 33s 1s/step - loss: 45.3713 - accuracy: 0.5805 - val_loss: 29.1402 - val_accuracy: 0.6627
# Epoch 3/30
# 33/33 [==============================] - 33s 993ms/step - loss: 21.1602 - accuracy: 0.5897 - val_loss: 21.0267 - val_accuracy: 0.5542
# Epoch 4/30
# 33/33 [==============================] - 34s 1s/step - loss: 10.9409 - accuracy: 0.6505 - val_loss: 13.8070 - val_accuracy: 0.6506
# Epoch 5/30
# 33/33 [==============================] - 33s 1s/step - loss: 9.6058 - accuracy: 0.6960 - val_loss: 11.7489 - val_accuracy: 0.5542
# Epoch 6/30
# 33/33 [==============================] - 33s 1s/step - loss: 5.1542 - accuracy: 0.7447 - val_loss: 13.3329 - val_accuracy: 0.5904
# Epoch 7/30
# 33/33 [==============================] - 34s 1s/step - loss: 8.8627 - accuracy: 0.6748 - val_loss: 6.9605 - val_accuracy: 0.6627
# Epoch 8/30
# 33/33 [==============================] - 34s 1s/step - loss: 9.1761 - accuracy: 0.7447 - val_loss: 23.3971 - val_accuracy: 0.6627
# Epoch 9/30
# 33/33 [==============================] - 35s 1s/step - loss: 8.3155 - accuracy: 0.7964 - val_loss: 10.6619 - val_accuracy: 0.6386
# Epoch 10/30
# 33/33 [==============================] - 35s 1s/step - loss: 2.3685 - accuracy: 0.8389 - val_loss: 7.8643 - val_accuracy: 0.6145
# Epoch 11/30
# 33/33 [==============================] - 37s 1s/step - loss: 2.7552 - accuracy: 0.8267 - val_loss: 9.3848 - val_accuracy: 0.6867
# Epoch 12/30
# 33/33 [==============================] - 40s 1s/step - loss: 3.2053 - accuracy: 0.8116 - val_loss: 8.1988 - val_accuracy: 0.6747
# Epoch 13/30
# 33/33 [==============================] - 34s 1s/step - loss: 2.1631 - accuracy: 0.8511 - val_loss: 11.6666 - val_accuracy: 0.6867
# Epoch 14/30
# 33/33 [==============================] - 34s 1s/step - loss: 2.0492 - accuracy: 0.8267 - val_loss: 14.4044 - val_accuracy: 0.6145
# Epoch 15/30
# 33/33 [==============================] - 34s 1s/step - loss: 6.4688 - accuracy: 0.7447 - val_loss: 24.9398 - val_accuracy: 0.5542
# Epoch 16/30
# 33/33 [==============================] - 33s 1s/step - loss: 5.2668 - accuracy: 0.7660 - val_loss: 11.7674 - val_accuracy: 0.6747
# Epoch 17/30
# 33/33 [==============================] - 42s 1s/step - loss: 1.5756 - accuracy: 0.8602 - val_loss: 9.5953 - val_accuracy: 0.6747
# Epoch 18/30
# 33/33 [==============================] - 37s 1s/step - loss: 0.9179 - accuracy: 0.9058 - val_loss: 8.1482 - val_accuracy: 0.5542
# Epoch 19/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.4054 - accuracy: 0.9392 - val_loss: 6.1452 - val_accuracy: 0.6747
# Epoch 20/30
# 33/33 [==============================] - 36s 1s/step - loss: 0.9774 - accuracy: 0.9210 - val_loss: 9.6629 - val_accuracy: 0.5783
# Epoch 21/30
# 33/33 [==============================] - 35s 1s/step - loss: 3.1097 - accuracy: 0.8571 - val_loss: 7.3147 - val_accuracy: 0.6627
# Epoch 22/30
# 33/33 [==============================] - 33s 1s/step - loss: 2.1053 - accuracy: 0.8571 - val_loss: 10.2776 - val_accuracy: 0.5301
# Epoch 23/30
# 33/33 [==============================] - 33s 1s/step - loss: 2.8892 - accuracy: 0.7872 - val_loss: 7.1735 - val_accuracy: 0.6506
# Epoch 24/30
# 33/33 [==============================] - 33s 1s/step - loss: 0.3432 - accuracy: 0.9392 - val_loss: 6.1696 - val_accuracy: 0.5783
# Epoch 25/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2388 - accuracy: 0.9666 - val_loss: 6.4134 - val_accuracy: 0.6506
# Epoch 26/30
# 33/33 [==============================] - 32s 989ms/step - loss: 0.1870 - accuracy: 0.9605 - val_loss: 7.9007 - val_accuracy: 0.6867
# Epoch 27/30
# 33/33 [==============================] - 33s 989ms/step - loss: 0.2023 - accuracy: 0.9666 - val_loss: 6.3854 - val_accuracy: 0.6265
# Epoch 28/30
# 33/33 [==============================] - 33s 996ms/step - loss: 0.1062 - accuracy: 0.9787 - val_loss: 5.9760 - val_accuracy: 0.6386
# Epoch 29/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.0350 - accuracy: 0.9909 - val_loss: 6.8068 - val_accuracy: 0.6747
# Epoch 30/30
# 33/33 [==============================] - 33s 1s/step - loss: 0.0755 - accuracy: 0.9757 - val_loss: 6.5862 - val_accuracy: 0.6988

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model_densenet.evaluate(X_test, test_labels_one_hot)
print(f"DenseNet121 Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 6.6739 - accuracy: 0.7404
# DenseNet121 Test Accuracy: 74.04%

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history_densenet.history['accuracy'])
plt.plot(history_densenet.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_densenet.history['loss'])
plt.plot(history_densenet.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Predict the test set results
y_pred = model_densenet.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure y_true is integer labels
y_true = y_test.astype(int)

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 4/4 [==============================] - 7s 1s/step

# %%
# Generate classification report
class_names = ['DME 0', 'DME 1', 'DME 2']
report = classification_report(y_true, y_pred_classes, target_names=class_names)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        DME 0       0.80      0.71      0.75        45
#        DME 1       0.60      0.30      0.40        10
#        DME 2       0.71      0.86      0.78        49
#
#     accuracy                           0.74       104
#    macro avg       0.70      0.62      0.64       104
# weighted avg       0.74      0.74      0.73       104
